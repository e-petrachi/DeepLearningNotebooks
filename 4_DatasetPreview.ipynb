# %% [markdown]
# # HOW TO
#     - Visualize photo preview

# %% [markdown]
# Import Packages

# %%
import numpy as np

# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import array_to_img, img_to_array, load_img, ImageDataGenerator
from PIL import Image

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import os

# %% [markdown]
# ---
# ### DATASET:

# %% [markdown]
# - Use and convert image to array

# %%
cat_0 = load_img('dogVScat/train/cats/cat.0.jpg')  
dog_0 = load_img('dogVScat/train/dogs/dog.3.jpg')

# %%
cat_x = img_to_array(cat_0) 
print("Dimensioni array:" ,cat_x.shape)
# Out:
# Dimensioni array: (374, 500, 3)

# %%
print(cat_x[:1])
# Out:
# [[[203. 164.  87.]
#   [203. 164.  87.]
#   [204. 165.  88.]
#   ...
#   [240. 201. 122.]
#   [239. 200. 121.]
#   [238. 199. 120.]]]

# %%
dog_x = img_to_array(dog_0) 
print("Dimensioni array:" ,dog_x.shape)
# Out:
# Dimensioni array: (375, 499, 3)

# %% [markdown]
# - Previews

# %%
print("Preview cat:")
plt.imshow(cat_0, interpolation='nearest')
plt.show()
# Out:
# Preview cat:

# %%
print("Preview dog:")
plt.imshow(dog_0, interpolation='nearest')
plt.show()
# Out:
# Preview dog:

# %% [markdown]
# ---
# ### FOLDERS and CATEGORIES:

# %% [markdown]
# - Folders

# %%
datadir = 'dogVScat'
cat1 = 'dogs'
cat2 = 'cats'

# %% [markdown]
# - Training set

# %%
target = os.chdir(datadir + "/train/" + cat1)
cat_1 = os.listdir()

# %%
target = os.chdir("../" + cat2)
cat_2 = os.listdir()

# %%
print("CAT1:",len(cat_1),"CAT2:",len(cat_2), "TOTAL:",len(cat_1)+len(cat_2))
# Out:
# CAT1: 5501 CAT2: 6054 TOTAL: 11555

# %% [markdown]
# - Validation set

# %%
target = os.chdir("../../validation/" + cat1)
cat_1_val = os.listdir()

# %%
target = os.chdir("../" + cat2)
cat_2_val = os.listdir()

# %%
print("CAT1:",len(cat_1_val),"CAT2:",len(cat_2_val), "TOTAL:",len(cat_1_val)+len(cat_2_val))
# Out:
# CAT1: 1302 CAT2: 1500 TOTAL: 2802

# %% [markdown]
# - Return to Home

# %%
os.chdir("../../../")

# %% [markdown]
# ---
# ### How to Predict:

# %%
model = load_model('keras_model.h5')
# Out:
# WARNING:tensorflow:From c:\users\e.petrachi\appdata\local\continuum\anaconda3\envs\tf-env\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\users\e.petrachi\appdata\local\continuum\anaconda3\envs\tf-env\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From c:\users\e.petrachi\appdata\local\continuum\anaconda3\envs\tf-env\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# ...

# %%
cat_x.shape
# Out:
# (374, 500, 3)

# %%
cat_x[:300,:300,:].shape
# Out:
# (300, 300, 3)

# %%
cat_x = cat_x[:300,:300,:]

# %%
cat_x = np.expand_dims(cat_x, axis=0)

# %%
cat_x.shape
# Out:
# (1, 300, 300, 3)

# %%
model.predict_classes(cat_x)
# Out:
# array([[0]])

# %%
dog_x = dog_x[:300,:300,:]

# %%
dog_x = np.expand_dims(dog_x, axis=0)

# %%
model.predict_classes(dog_x)
# Out:
# array([[1]])
